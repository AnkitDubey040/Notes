# %%
import pandas as pd
import mysql.connector as conn

# %%
mydb = conn.connect(host = "Localhost" , user ="root" , passwd = "India123")

# %%
cursor = mydb.cursor()
cursor.execute("Show Databases")
cursor.fetchall()
# Out:
# [('bank',),
#  ('database2',),
#  ('databasetesthai',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('world',)]

# %%
cursor.execute("Create database Dressdb")

# %%
df1 = pd.read_excel("E:\DATA SCIENCE\data fsds_\Dress Sales.xlsx")
df1
# Out:
#        Dress_ID    D1    D2    D3    D4    D5    D6    D7    D8    D9  ...  \
# 0    1006032852  2114  2274  2491  2660  2727  2887  2930  3119  3204  ...
# 1    1212192089   151   275   570   750   813  1066  1164  1558  1756  ...
# 2    1190380701     6     7     7     7     8     8     9    10    10  ...
# 3     966005983  1005  1128  1326  1455  1507  1621  1637  1723  1746  ...
# 4     876339541   996  1175  1304  1396  1432  1559  1570  1638  1655  ...
# ..          ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 495   713391965     0     0     0   560   554   544   537   525   519  ...
# 496   722565148     0     0     0   875   866   861   854   850   844  ...
# 497   532874347     0     0     0   734   728   726   715   694   690  ...
# 498   655464934     0     0     0   254   259   261   263   268   270  ...
# 499   919930954     0     0     0   538   545   558   563   578   585  ...
#
# ...

# %%
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://root:India123@Localhost/Dressdb")

# %%
df1.to_sql("dresssalestab" ,index=None, con = engine)
# Out:
# 500

# %%
df2=pd.read_excel("E:\DATA SCIENCE\data fsds_\Attribute DataSet.xlsx")
df2
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
df2.to_sql("attributetab" ,index = None , con=engine)
# Out:
# 500

# %%
cursor.execute("use dressdb")

# %%
df3 = cursor.execute("select dresssalestab.Dress_ID from dresssalestab left join attributetab on dresssalestab.Dress_ID = attributetab.Dress_ID")

# %%
cursor.fetchall()
# Out:
# [(1006032852,),
#  (1212192089,),
#  (1190380701,),
#  (966005983,),
#  (876339541,),
#  (1068332458,),
#  (1220707172,),
#  (1219677488,),
#  (1219677488,),
#  (1113094204,),
#  (985292672,),
#  (1117293701,),
#  (898481530,),
#  (957723897,),
#  (749031896,),
#  (1055411544,),
#  (1162628131,),
#  (624314841,),
#  (830467746,),
#  (840857118,),
#  (1113221101,),
#  (861754372,),
#  (856178100,),
#  (1122989777,),
#  (840516484,),
#  (768517084,),
#  (1139843344,),
#  (1004212992,),
#  (1235426503,),
#  (942808364,),
#  (629131530,),
#  (851945460,),
#  (1150275464,),
#  (1026634314,),
#  (978773911,),
#  (827791337,),
#  (640823350,),
#  (801861988,),
#  (1060207186,),
#  (1054679816,),
#  (941190190,),
#  (943844640,),
#  (661795386,),
#  (875312593,),
#  (971387676,),
#  (1021185637,),
#  (1163826114,),
#  (735635595,),
#  (1175184188,),
#  (679415939,),
#  (884147971,),
#  (841203385,),
#  (841203385,),
#  (1117997056,),
#  (1160536550,),
#  (828623528,),
#  (763708514,),
# ...

# %%
cursor.execute("select Style,count(*) from attributetab group by Style ")
cursor.fetchall()
# Out:
# [('Sexy', 76),
#  ('Casual', 232),
#  ('vintage', 25),
#  ('Brief', 18),
#  ('cute', 45),
#  ('bohemian', 24),
#  ('Novelty', 8),
#  ('Flare', 2),
#  ('party', 51),
#  ('work', 17),
#  ('OL', 1),
#  ('fashion', 1)]

# %%
cursor.execute("select count(*) from attributetab where Recommendation=0")
cursor.fetchall()
# Out:
# [(290,)]

# %%
cursor.execute("select count(*) from attributetab where Recommendation=1")
cursor.fetchall()
# Out:
# [(210,)]

# %%
df1
# Out:
#        Dress_ID    D1    D2    D3    D4    D5    D6    D7    D8    D9  ...  \
# 0    1006032852  2114  2274  2491  2660  2727  2887  2930  3119  3204  ...
# 1    1212192089   151   275   570   750   813  1066  1164  1558  1756  ...
# 2    1190380701     6     7     7     7     8     8     9    10    10  ...
# 3     966005983  1005  1128  1326  1455  1507  1621  1637  1723  1746  ...
# 4     876339541   996  1175  1304  1396  1432  1559  1570  1638  1655  ...
# ..          ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 495   713391965     0     0     0   560   554   544   537   525   519  ...
# 496   722565148     0     0     0   875   866   861   854   850   844  ...
# 497   532874347     0     0     0   734   728   726   715   694   690  ...
# 498   655464934     0     0     0   254   259   261   263   268   270  ...
# 499   919930954     0     0     0   538   545   558   563   578   585  ...
#
# ...

# %%
cursor.execute("select  Dress_ID, coalesce(D1,0)+coalesce(D2,0)+coalesce(D3,0)+coalesce(D4,0)+coalesce(D5,0)+coalesce(D6,0)+coalesce(D7,0)+coalesce(D8,0)+coalesce(D9,0)+coalesce(D10,0)+coalesce(D11,0)+coalesce(D12,0)+coalesce(D13,0)+coalesce(D14,0)+coalesce(D15,0)+coalesce(D16,0)+coalesce(D17,0)+coalesce(D18,0)+coalesce(D19,0)+coalesce(D20,0)+coalesce(D21,0)+coalesce(D22,0)+coalesce(D23,0) as Total_Sale from dresssalestab")
cursor.fetchall()
# Out:
# [(1006032852, 75979.0),
#  (1212192089, 52256.0),
#  (1190380701, 223.0),
#  (966005983, 39691.0),
#  (876339541, 44077.0),
#  (1068332458, 457.0),
#  (1220707172, 7328.0),
#  (1219677488, 3248.0),
#  (1113094204, 494.0),
#  (985292672, 300.0),
#  (1117293701, 1911.0),
#  (898481530, 2842.0),
#  (957723897, 49983.0),
#  (749031896, 75346.0),
#  (1055411544, 1095.0),
#  (1162628131, 2319.0),
#  (624314841, 47998.0),
#  (830467746, 401.0),
#  (840857118, 299.0),
#  (1113221101, 9998.0),
#  (861754372, 6175.0),
#  (856178100, 31467.0),
#  (1122989777, 5216.0),
#  (840516484, 42347.0),
#  (768517084, 107.0),
#  (1139843344, 518.0),
#  (1004212992, 48440.0),
#  (1235426503, 4696.0),
#  (942808364, 11518.0),
#  (629131530, 155927.0),
#  (851945460, 26496.0),
#  (1150275464, 5738.0),
#  (1026634314, 18184.0),
#  (978773911, 23200.0),
#  (827791337, 41875.0),
#  (640823350, 29528.0),
#  (801861988, 32342.0),
#  (1060207186, 1820.0),
#  (1054679816, 12987.0),
#  (941190190, 11693.0),
# ...

# %%
 pd.read_excel("E:\DATA SCIENCE\data fsds_\Dress Sales.xlsx")
# Out:
#        Dress_ID    D1    D2    D3    D4    D5    D6    D7    D8    D9  ...  \
# 0    1006032852  2114  2274  2491  2660  2727  2887  2930  3119  3204  ...
# 1    1212192089   151   275   570   750   813  1066  1164  1558  1756  ...
# 2    1190380701     6     7     7     7     8     8     9    10    10  ...
# 3     966005983  1005  1128  1326  1455  1507  1621  1637  1723  1746  ...
# 4     876339541   996  1175  1304  1396  1432  1559  1570  1638  1655  ...
# ..          ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 495   713391965     0     0     0   560   554   544   537   525   519  ...
# 496   722565148     0     0     0   875   866   861   854   850   844  ...
# 497   532874347     0     0     0   734   728   726   715   694   690  ...
# 498   655464934     0     0     0   254   259   261   263   268   270  ...
# 499   919930954     0     0     0   538   545   558   563   578   585  ...
#
# ...

# %%
df2.to_json("jsonattributedataset.json")

# %%
pip install pymongo
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting pymongo
#
# ...

# %%
pip install pymongo[srv]
# Out:
# ...
#
# ...
#   Using cached dnspython-2.2.1-py3-none-any.whl (269 kB)
# ...

# %%
#restart the kernal after installing the packadges
import pymongo

client = pymongo.MongoClient("mongodb+srv://ankitdubey:ankitmongo04@cluster0.ctr9gra.mongodb.net/?retryWrites=true&w=majority")
db = client.test
database = ["DressDb"]
collection = database["Attribute"]
with open('jsonattributedataset.json') as file:
    file_data = json.load(file)
if isinstance(file_data, list):
    Collection.insert_many(file_data) 
else:
    Collection.insert_one(file_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 7>()
#       5 db = client.test
#       6 database = ["DressDb"]
# ----> 7 collection = database["Attribute"]
#       8 with open('jsonattributedataset.json') as file:
#       9     file_data = json.load(file)
#
# TypeError: list indices must be integers or slices, not str

# %%
df5 = pd.read_json("C:\Users\HP\Jupyter codes\jsonattributedataset.json")
df5
# Out:
#   Input In [13]
#     df5 = pd.read_json("C:\Users\HP\Jupyter codes\jsonattributedataset.json")
#                                                                             ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
