# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.plot()  #describe function like for numerical columns 
# by default we get a line graph
# Out:
# <AxesSubplot:>

# %%
# to get different kind of graph
df.plot(kind = 'area')
# Out:
# <AxesSubplot:>

# %%
# to change the color or Intensity or darkness of color
df.plot(kind = 'area' ,alpha= 0.4)
# Out:
# <AxesSubplot:>

# %%
df.plot(kind = 'area' ,alpha= 0.05)
# Out:
# <AxesSubplot:>

# %%
# to make it not completely overlap
df.plot(kind = 'area' ,alpha= 0.8 , stacked = False)
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# say we want to compare some relations :
df.plot.scatter(x='sepal_length' , y ='sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df.plot.scatter(x='sepal_length' , y ='petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
# to find relation in more depth with color or control 
df.plot.scatter(x='sepal_length' , y ='petal_length' , c = 'sepal_width')


# sepal_width represent intensity
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
# for size of the dots
df.plot.scatter(x='sepal_length' , y ='petal_length' , c = 'sepal_width' , s =100)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x='sepal_length' , y ='petal_length' , c = 'sepal_width' , s = 0.3)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
# to make it dynamic
df.plot.scatter(x='sepal_length' , y ='petal_length' , c = 'petal_width', s = df['sepal_length']*20)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
# hexbin plot here name of parameter change
df.plot.hexbin(x ='sepal_length' , y ='petal_length',gridsize=10,cmap="viridis")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
# 3-D plot

# %%
from mpl_toolkits import mplot3d

# %%
# create a data 
x = np.linspace(-1,6 , 30)
x
# Out:
# array([-1.        , -0.75862069, -0.51724138, -0.27586207, -0.03448276,
#         0.20689655,  0.44827586,  0.68965517,  0.93103448,  1.17241379,
#         1.4137931 ,  1.65517241,  1.89655172,  2.13793103,  2.37931034,
#         2.62068966,  2.86206897,  3.10344828,  3.34482759,  3.5862069 ,
#         3.82758621,  4.06896552,  4.31034483,  4.55172414,  4.79310345,
#         5.03448276,  5.27586207,  5.51724138,  5.75862069,  6.        ])

# %%
y = np.linspace(-1,6 , 30 )
y
# Out:
# array([-1.        , -0.75862069, -0.51724138, -0.27586207, -0.03448276,
#         0.20689655,  0.44827586,  0.68965517,  0.93103448,  1.17241379,
#         1.4137931 ,  1.65517241,  1.89655172,  2.13793103,  2.37931034,
#         2.62068966,  2.86206897,  3.10344828,  3.34482759,  3.5862069 ,
#         3.82758621,  4.06896552,  4.31034483,  4.55172414,  4.79310345,
#         5.03448276,  5.27586207,  5.51724138,  5.75862069,  6.        ])

# %%
z = x+y

# %%
z
# Out:
# array([-2.        , -1.51724138, -1.03448276, -0.55172414, -0.06896552,
#         0.4137931 ,  0.89655172,  1.37931034,  1.86206897,  2.34482759,
#         2.82758621,  3.31034483,  3.79310345,  4.27586207,  4.75862069,
#         5.24137931,  5.72413793,  6.20689655,  6.68965517,  7.17241379,
#         7.65517241,  8.13793103,  8.62068966,  9.10344828,  9.5862069 ,
#        10.06896552, 10.55172414, 11.03448276, 11.51724138, 12.        ])

# %%
# first define dimn  
ax = plt.axes(projection = '3d')
# now giving axis
ax.plot3D(x,y,z)
# defining axis's data labels
ax.set_xlabel('x1')
ax.set_ylabel('y1')
ax.set_zlabel('z1')
# Out:
# Text(0.5, 0, 'z1')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# plotting 3d graph for dataframe
ax = plt.axes(projection = '3d')
ax.plot3D(df['sepal_length'],df['sepal_width'],df['petal_length'])
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')
ax.set_zlabel('petal_length')
# Out:
# Text(0.5, 0, 'petal_length')

# %%
# to increase the size of the graph and for title
df.plot(figsize= (20,5) , title ='Length and Width')
# Out:
# <AxesSubplot:title={'center':'Length and Width'}>

# %%
# Bar graph
df.iloc[2:7].plot(kind ='bar', figsize = (10,5))
# Out:
# <AxesSubplot:>

# %%
df.iloc[2:7]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa

# %%
# horizontal bar 
df.iloc[2:7].plot(kind ='barh', figsize = (10,5))
# Out:
# <AxesSubplot:>

# %%
# histogram 
df.plot(kind= 'hist' , figsize = (20,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# for single column
df['sepal_length'].plot(kind = 'hist' , figsize = (20,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# hist function
# for color 
df.hist(figsize=(20,10) , color = 'g', alpha= .9)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
# changing color with hexadecimal code
df.hist(figsize=(20,10) , color = '#EDC128', alpha= .9)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df.iplot()
# Out:
# <div>                            <div id="9be3ab15-eb4f-4f17-9828-19b594860a88" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x = 'sepal_length' , y = 'sepal_width',kind = 'scatter' , mode = 'markers')
# mode is for dots
# Out:
# <div>                            <div id="c03be7cf-6879-4799-b2bb-187d771de1bb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x ='sepal_length' ,y ='sepal_width' ,z ='petal_length'  ,size = 'sepal_length' ,kind = 'bubble3d')
# Out:
# <div>                            <div id="491b486f-5db7-4507-8a1f-091f7ac8910f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x ='sepal_length' ,y ='sepal_width' ,size = 'sepal_length' ,kind = 'bubble')
# Out:
# <div>                            <div id="47ec9544-2b78-416e-827c-3aa941c106e1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1 = sns.load_dataset('tips')

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1.iplot(x = 'total_bill' , y = 'tip' , kind = 'scatter', mode = 'markers', xTitle ='Total_bill', yTitle = 'Tip', title = 'Tip vs total Bill')
# Out:
# <div>                            <div id="8dd1060e-49b3-4547-9c90-0f2bdbfd8eda" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1.plot(x = 'total_bill' , y = 'tip' , kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# using seaborn for plots:

# %%
# and using style , hue for grouping

# %%
sns.relplot(x = 'total_bill', y = 'tip' , data = df1 , hue = 'size',style = 'size')

# %%
df1['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.relplot(x = 'total_bill', y = 'tip' , data = df1 , hue = 'smoker')

# %%
sns.relplot(x = 'total_bill', y = 'tip' , data = df1 , style = 'smoker', hue = 'time')

# %%
sns.relplot(x = 'total_bill', y = 'tip' , data = df1 , style = 'sex', hue = 'time')

# %%
# to seperate data

# %%
sns.relplot(x = 'total_bill' ,y = 'tip' , data = df1 , col ='time' )

# %%
sns.relplot(x = 'sepal_length' ,y = 'sepal_width' , data = df , col ='species' )

# %%
sns.relplot(x = 'total_bill' ,y = 'tip' , data = df1 , col ='day' )

# %%
# catplot for categorical plot

# %%
sns.catplot( x = 'day' , y = 'total_bill' , data = df1)

# %%
# pair plot for comparison of all  numerical data in df1
sns.pairplot(df1)

# %%
sns.pairplot(df)

# %%
# in plotly cuuflinks if we want same thing
df.scatter_matrix()
# Out:
# <div>                            <div id="acf4186c-0e64-457c-963a-15f087e63ed4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np


# make data
np.random.seed(1)
x = 4 + np.random.normal(0, 1.5, 200)

# plot:
fig, ax = plt.subplots()

ax.hist(df['sepal_length'], bins=8, linewidth=0.9, edgecolor="white")

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 56), yticks=np.linspace(0, 56, 9))

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

fig, ax = plt.subplots()

x = np.arange(0, 2*np.pi, 0.01)
line, = ax.plot(x, np.sin(x))


def animate(i):
    line.set_ydata(np.sin(x + i / 50))  # update the data.
    return line,


ani = animation.FuncAnimation(
    fig, animate, interval=20, blit=True, save_count=50)

# To save the animation, use e.g.
#
# ani.save("movie.mp4")
#
# or
#
# writer = animation.FFMpegWriter(
#     fps=15, metadata=dict(artist='Me'), bitrate=1800)
# ani.save("movie.mp4", writer=writer)

plt.show()

# %%
# combining two diff kind of plots
sns.jointplot(x =df1.total_bill , y = df1.tip )

# %%
# changing kind
sns.jointplot(x =df1.total_bill , y = df1.tip,kind = 'hex' )

# %%
# regplot give regression data 


sns.regplot(x = df1.total_bill , y = df1.tip)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.regplot(x = df1.total_bill , y = df1.tip)
sns.set(rc={'figure.figsize':(30,20)})

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 15))

# Load the example car crash dataset
crashes = sns.load_dataset("car_crashes").sort_values("total", ascending=False)

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="total", y="abbrev", data=crashes,
            label="Total", color="b")

# Plot the crashes where alcohol was involved
sns.set_color_codes("muted")
sns.barplot(x="alcohol", y="abbrev", data=crashes,
            label="Alcohol-involved", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0, 24), ylabel="country",xlabel="Automobile collisions per billion miles")
sns.despine(left=True, bottom=True)

# %%
sns.load_dataset("car_crashes")
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
# fromm plotly exprss documentation

# %%
import plotly.express as px

fig = px.scatter(df1, x="total_bill", y="tip", color="time")
fig.show()
# Out:
# <div>                            <div id="04adc346-efed-4f98-84de-55c0502c7cb9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("04adc346-efed-4f98-84de-55c0502c7cb9")) {                    Plotly.newPlot(                        "04adc346-efed-4f98-84de-55c0502c7cb9",                        [{"hovertemplate":"time=Dinner<br>total_bill=%{x}<br>tip=%{y}<extra></extra>","legendgroup":"Dinner","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Dinner","orientation":"v","showlegend":true,"x":[16.99,10.34,21.01,23.68,24.59,25.29,8.77,26.88,15.04,14.78,10.27,35.26,15.42,18.43,14.83,21.58,10.33,16.29,16.97,20.65,17.92,20.29,15.77,39.42,19.82,17.81,13.37,12.69,21.7,19.65,9.55,18.35,15.06,20.69,17.78,24.06,16.31,16.93,18.69,31.27,16.04,17.
# ...

# %%
import plotly.express as px

fig = px.bar(df1, x="sex", y="total_bill", color="smoker", barmode="group")
fig.show()
# Out:
# <div>                            <div id="fd59f8be-e479-47dc-8730-566fce47ee8e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fd59f8be-e479-47dc-8730-566fce47ee8e")) {                    Plotly.newPlot(                        "fd59f8be-e479-47dc-8730-566fce47ee8e",                        [{"alignmentgroup":"True","hovertemplate":"smoker=No<br>sex=%{x}<br>total_bill=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"textposition":"auto","x":["Female","Male","Male","Male","Female","Male","Male","Male","Male","Male","Male","Female","Male","Male","Female","Male","Female","Male","Female","Male","Male","Female","Female","Male","Male","Male","Male
# ...

# %%
cufflinks - https://github.com/santosjorge/cufflinks
plotly - https://plotly.com/python/plotly-express/
seaborn - https://seaborn.pydata.org/index.html
matplotlib - https://matplotlib.org/stable/index.html
