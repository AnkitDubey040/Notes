# %% [markdown]
# ##### Resource:
# https://docs.google.com/spreadsheets/d/1z4EWsGxw0YBQ1-51xZDxYNlB3ngJzg4t/edit?usp=sharing&ouid=118282207943964605599&rtpof=true&sd=true
# https://docs.google.com/spreadsheets/d/1z2n8aeFF5GoohQ3KCZw8bKogezpO9l4k/edit?usp=sharing&ouid=118282207943964605599&rtpof=true&sd=true
#
# ###### QUESTIONS:
# 1 .Find out there avarage rating on weekly basis keep this in a mind that they take two days of leave.
# 2 .Total working days for each agents.
# 3. Total query that you hvae taken.
# 4. total Feedback that you have received.
# 5. a agent name who have average rating between 3.5 to 4.
# 6 . Agent name who have rating lesss then 3.5
# 7 . agent name who have rating more then 4.5
# 8 . how many feedaback agents have received more then 4.5 average.
# 9 . average weekly response time for each agent
# 10 . average weekely resolution time for each agents
# 11 . list of all agents name
# 12 . percentage of chat on which they have received a feedback
# 13 . Total contributation hour for each and every agents weekly basis
# 14. total percentage of active hour for a month

# %%
import pandas as pd

# %%
df1 = pd.read_csv("E:\DATA SCIENCE\data fsds_\AgentPerformance.csv" , index_col = 'SL No'  )
# Note that the location of csv file can vary depending on your system

# %%
df1
# Out:
#             Date          Agent Name  Total Chats Average Response Time  \
# SL No
# 1      7/30/2022        Prerna Singh           11               0:00:38
# 2      7/30/2022       Nandani Gupta           11               0:01:15
# 3      7/30/2022          Ameya Jain           14               0:00:30
# 4      7/30/2022       Mahesh Sarade           14               0:01:04
# 5      7/30/2022              Swati            14               0:01:11
# ...          ...                 ...          ...                   ...
# 2156    7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2157    7/1/2022             Nitin M            0               0:00:00
# 2158    7/1/2022              Vivek             0               0:00:00
# 2159    7/1/2022       Ayushi Mishra            0               0:00:00
# 2160    7/1/2022  Chaitra K Hiremath            0               0:00:00
#
#       Average Resolution Time  Average Rating  Total Feedback
# SL No
# ...

# %%
df1.dtypes
# Out:
# Date                        object
# Agent Name                  object
# Total Chats                  int64
# Average Response Time       object
# Average Resolution Time     object
# Average Rating             float64
# Total Feedback               int64
# dtype: object

# %% [markdown]
# ###### Ans 1:
# To find weekly rating of each Agent

# %%
# First we need to convert the Date column into datetime datatype
df1['Date'] = pd.to_datetime(df1['Date'])

# %%
df1.dtypes
# Out:
# Date                       datetime64[ns]
# Agent Name                         object
# Total Chats                         int64
# Average Response Time              object
# Average Resolution Time            object
# Average Rating                    float64
# Total Feedback                      int64
# dtype: object

# %%
#creating another column named week 
df1['Week'] = df1['Date'].dt.week
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10824\1901631313.py:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df1['Week'] = df1['Date'].dt.week

# %%
df1
# Out:
#             Date          Agent Name  Total Chats Average Response Time  \
# SL No
# 1     2022-07-30        Prerna Singh           11               0:00:38
# 2     2022-07-30       Nandani Gupta           11               0:01:15
# 3     2022-07-30          Ameya Jain           14               0:00:30
# 4     2022-07-30       Mahesh Sarade           14               0:01:04
# 5     2022-07-30              Swati            14               0:01:11
# ...          ...                 ...          ...                   ...
# 2156  2022-07-01   Sowmiya Sivakumar            0               0:00:00
# 2157  2022-07-01             Nitin M            0               0:00:00
# 2158  2022-07-01              Vivek             0               0:00:00
# 2159  2022-07-01       Ayushi Mishra            0               0:00:00
# 2160  2022-07-01  Chaitra K Hiremath            0               0:00:00
#
#       Average Resolution Time  Average Rating  Total Feedback  Week
# SL No
# ...

# %%
df2 =  df1[ ['Agent Name' , 'Average Rating' , 'Week']]

# %%
df2
# Out:
#                Agent Name  Average Rating  Week
# SL No
# 1            Prerna Singh            4.11    30
# 2           Nandani Gupta            3.14    30
# 3              Ameya Jain            4.55    30
# 4           Mahesh Sarade            4.71    30
# 5                  Swati             3.67    30
# ...                   ...             ...   ...
# 2156    Sowmiya Sivakumar            0.00    26
# 2157              Nitin M            0.00    26
# 2158               Vivek             0.00    26
# 2159        Ayushi Mishra            0.00    26
# 2160   Chaitra K Hiremath            0.00    26
#
# [2160 rows x 3 columns]

# %%
# to find weekly rating of each agent : 
df3 = df2.groupby(['Agent Name','Week'])['Average Rating'].mean().to_frame()
# note that it is not overall average rating but weekly average rating of each agent

# %%
df3.head(20)
# Out:
#                     Average Rating
# Agent Name    Week
# Abhishek      26          0.000000
#               27          0.000000
#               28          0.000000
#               29          0.000000
#               30          0.000000
# Aditya        26          0.000000
#               27          0.000000
#               28          0.000000
#               29          0.000000
#               30          0.000000
# Aditya Shinde 26          2.566667
#               27          3.225714
#               28          3.390000
#               29          0.000000
#               30          0.000000
# Aditya_iot    26          0.000000
#               27          1.232857
#               28          2.928571
#               29          3.114286
#               30          3.238333

# %% [markdown]
# ###### Ans2:
# To find no. of working days for each agent

# %%
# first create a dataframe consisting list of agents who have interacted and  had chat i.e. Total Chats > 0
df4 = df1[df1['Total Chats'] > 0]
df4
# Out:
#             Date          Agent Name  Total Chats Average Response Time  \
# SL No
# 1     2022-07-30        Prerna Singh           11               0:00:38
# 2     2022-07-30       Nandani Gupta           11               0:01:15
# 3     2022-07-30          Ameya Jain           14               0:00:30
# 4     2022-07-30       Mahesh Sarade           14               0:01:04
# 5     2022-07-30              Swati            14               0:01:11
# ...          ...                 ...          ...                   ...
# 2102  2022-07-01       Jaydeep Dixit           25               0:01:15
# 2103  2022-07-01  Shivananda Sonwane           23               0:01:24
# 2104  2022-07-01      Khushboo Priya           24               0:01:46
# 2105  2022-07-01     Hrisikesh Neogi           15               0:01:05
# 2106  2022-07-01              Tarun            22               0:00:00
#
#       Average Resolution Time  Average Rating  Total Feedback  Week
# SL No
# ...

# %%
# nuique returns no of unique values for each column
df5 = df4.groupby('Agent Name')['Date'].nunique().to_frame()
# rest of agents whose name is not in the dataframe have 0 working days

# %%
df5['Working days'] = df5['Date']

# %%
df5
# Out:
#                         Date  Working days
# Agent Name
# Aditya Shinde             12            12
# Aditya_iot                17            17
# Ameya Jain                15            15
# Anirudh                    7             7
# Ankitjha                   3             3
# Anurag Tiwari              2             2
# Aravind                   14            14
# Ashad Nasim                2             2
# Ayushi Mishra             24            24
# Bharath                   19            19
# Boktiar Ahmed Bappy       26            26
# Chaitra K Hiremath         6             6
# Deepranjan Gupta          21            21
# Dibyanshu                  1             1
# Harikrishnan Shaji        19            19
# Hitesh Choudhary           1             1
# Hrisikesh Neogi           21            21
# Ishawant Kumar            24            24
# Jawala Prakash            25            25
# Jayant Kumar               8             8
# ...

# %% [markdown]
# ###### Ans3:
# Total query by each agent

# %%
df1.groupby('Agent Name')['Total Chats'].sum().to_frame()
# Out:
#                Total Chats
# Agent Name
# Abhishek                 0
# Aditya                   0
# Aditya Shinde          277
# Aditya_iot             231
# Amersh                   0
# ...                    ...
# Uday Mishra              0
# Vasanth P                0
# Vivek                   44
# Wasim                  433
# Zeeshan                542
#
# [70 rows x 1 columns]

# %% [markdown]
# ###### Ans 4:
# Total feedback received:

# %%
df1.groupby('Agent Name')['Total Feedback'].sum().to_frame()
# Out:
#                Total Feedback
# Agent Name
# Abhishek                    0
# Aditya                      0
# Aditya Shinde             153
# Aditya_iot                131
# Amersh                      0
# ...                       ...
# Uday Mishra                 0
# Vasanth P                   0
# Vivek                      20
# Wasim                     284
# Zeeshan                   335
#
# [70 rows x 1 columns]

# %% [markdown]
# ###### Asn5:
# Agents having average rating between 3.5 and 4

# %%
# First we find overall average rating of each agent 
df6= df4.groupby('Agent Name')['Average Rating'].mean().to_frame()

# %%
df6
# Out:
#                         Average Rating
# Agent Name
# Aditya Shinde                 4.500833
# Aditya_iot                    4.138824
# Ameya Jain                    4.439333
# Anirudh                       2.764286
# Ankitjha                      2.666667
# Anurag Tiwari                 2.750000
# Aravind                       4.674286
# Ashad Nasim                   2.500000
# Ayushi Mishra                 4.352500
# Bharath                       4.711053
# Boktiar Ahmed Bappy           4.116923
# Chaitra K Hiremath            4.323333
# Deepranjan Gupta              4.123810
# Dibyanshu                     0.000000
# Harikrishnan Shaji            4.167895
# Hitesh Choudhary              0.000000
# Hrisikesh Neogi               4.480476
# Ishawant Kumar                4.429167
# Jawala Prakash                4.166400
# Jayant Kumar                  4.007500
# Jaydeep Dixit                 4.524286
# Khushboo Priya                4.273462
# Madhulika G                   4.373333
# ...

# %%
#now we will find agents having rating between 3.5 and 4
df6[(df6['Average Rating'] > 3.5 ) & (df6['Average Rating'] < 4.0)]
# Out:
#             Average Rating
# Agent Name
# Mithun S          3.931667
# Shivan K          3.874545

# %% [markdown]
# ###### Ans6:
# Agent with rating less than 3.5

# %%
df6[df6['Average Rating'] < 3.5 ]
# Out:
#                   Average Rating
# Agent Name
# Anirudh                 2.764286
# Ankitjha                2.666667
# Anurag Tiwari           2.750000
# Ashad Nasim             2.500000
# Dibyanshu               0.000000
# Hitesh Choudhary        0.000000
# Mahak                   3.000000
# Maneesh                 1.666667
# Mukesh Rao              2.556667
# Samprit                 0.000000
# Tarun                   1.500000
# Vivek                   3.004000

# %% [markdown]
# ###### Ans7 :
# Agents with rating more than 4.5

# %%
df6[(df6['Average Rating'] > 4.5 ) ]
# Out:
#                     Average Rating
# Agent Name
# Aditya Shinde             4.500833
# Aravind                   4.674286
# Bharath                   4.711053
# Jaydeep Dixit             4.524286
# Mukesh                    4.645000
# Saikumarreddy N           4.570000
# Shivananda Sonwane        4.535000
# Shubham Sharma            4.607619
# Sudhanshu Kumar           5.000000
# Suraj S Bilgi             4.680000

# %% [markdown]
# ###### Ans8 :
# No of feedback of Agents having rating avg more than 4.5

# %%
# agents having rating above 4.5 
df7 = df6[(df6['Average Rating'] > 4.5 ) ]
# now finding no of feedbacks for each 
df7['Feedback'] = df1.groupby('Agent Name')['Total Feedback'].sum().to_frame()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10824\3596004809.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df7['Feedback'] = df1.groupby('Agent Name')['Total Feedback'].sum().to_frame()

# %%
df7
# Out:
#                     Average Rating  Feedback
# Agent Name
# Aditya Shinde             4.500833       153
# Aravind                   4.674286       233
# Bharath                   4.711053       247
# Jaydeep Dixit             4.524286       305
# Mukesh                    4.645000        17
# Saikumarreddy N           4.570000       290
# Shivananda Sonwane        4.535000       263
# Shubham Sharma            4.607619       300
# Sudhanshu Kumar           5.000000         2
# Suraj S Bilgi             4.680000        15

# %% [markdown]
# ###### Ans9:
# Average weekly response time for each agent

# %%
# first convert Average response time column to time datatype
df1['Average Response Time'] = pd.to_timedelta(df1['Average Response Time'])

# %%
df1.dtypes
# Out:
# Date                        datetime64[ns]
# Agent Name                          object
# Total Chats                          int64
# Average Response Time      timedelta64[ns]
# Average Resolution Time             object
# Average Rating                     float64
# Total Feedback                       int64
# Week                                 int64
# dtype: object

# %%
df8 = df1.groupby(['Agent Name' , 'Week'])['Average Response Time'].mean().to_frame()

# %%
df8
# Out:
#                     Average Response Time
# Agent Name Week
# Abhishek   26             0 days 00:00:00
#            27             0 days 00:00:00
#            28             0 days 00:00:00
#            29             0 days 00:00:00
#            30             0 days 00:00:00
# ...                                   ...
# Zeeshan    26             0 days 00:00:00
#            27   0 days 00:00:23.571428571
#            28   0 days 00:02:03.428571428
#            29   0 days 00:01:02.857142857
#            30   0 days 00:01:03.833333333
#
# [350 rows x 1 columns]

# %% [markdown]
# ###### Ans10:
# Avg weekly resolution time for each agent

# %%
# first convert Average resolution time column to time datatype
df1['Average Resolution Time'] = pd.to_timedelta(df1['Average Resolution Time'])

# %%
df1.dtypes
# Out:
# Date                        datetime64[ns]
# Agent Name                          object
# Total Chats                          int64
# Average Response Time      timedelta64[ns]
# Average Resolution Time    timedelta64[ns]
# Average Rating                     float64
# Total Feedback                       int64
# Week                                 int64
# dtype: object

# %%
df1.groupby(['Agent Name' , 'Week'])['Average Resolution Time'].mean().to_frame()
# Out:
#                   Average Resolution Time
# Agent Name Week
# Abhishek   26             0 days 00:00:00
#            27             0 days 00:00:00
#            28             0 days 00:00:00
#            29             0 days 00:00:00
#            30             0 days 00:00:00
# ...                                   ...
# Zeeshan    26             0 days 00:00:00
#            27             0 days 00:05:23
#            28   0 days 00:16:24.285714285
#            29   0 days 00:13:14.285714285
#            30      0 days 00:12:53.500000
#
# [350 rows x 1 columns]

# %% [markdown]
# ##### Ans11 :
# list of all agent names

# %%
list(df1['Agent Name'].unique())
# Out:
# ['Prerna Singh',
#  'Nandani Gupta',
#  'Ameya Jain',
#  'Mahesh Sarade',
#  'Swati ',
#  'Mukesh ',
#  'Saikumarreddy N',
#  'Sanjeev Kumar',
#  'Shubham Sharma',
#  'Nishtha Jain',
#  'Manjunatha A',
#  'Khushboo Priya',
#  'Suraj S Bilgi',
#  'Harikrishnan Shaji',
#  'Hrisikesh Neogi',
#  'Shivan K',
#  'Sowmiya Sivakumar',
#  'Madhulika G',
#  'Mithun S',
#  'Hitesh Choudhary',
#  'Sanjeevan ',
#  'Anirudh ',
#  'Shiva Srivastava',
#  'Dibyanshu ',
#  'Ashish ',
#  'Uday Mishra',
#  'Aditya Shinde',
#  'Jayant Kumar',
#  'Aditya_iot ',
#  'Prabir Kumar Satapathy',
#  'Saurabh Shukla',
#  'Wasim ',
#  'Samprit ',
#  'Maitry ',
#  'Abhishek ',
#  'Rishav Dash',
#  'Aravind ',
#  'Tarun ',
#  'Muskan Garg',
#  'Ankit Sharma',
#  'Bharath ',
#  'Ashad Nasim',
#  'Vasanth P',
#  'Aditya ',
#  'Amersh ',
#  'Sandipan Saha',
#  'Ineuron Intelligence ',
#  'Mahak ',
#  'Mukesh Rao ',
#  'Zeeshan ',
#  'Anurag Tiwari',
#  'Ankitjha ',
#  'Saif Khan',
#  'Jaydeep Dixit',
# ...

# %% [markdown]
# ###### Ans12:
# percentage of chat on which they have received a feedback

# %%
df9 = df4.groupby('Agent Name')['Total Chats'].sum().to_frame()
df9['Total Feedback'] = df4.groupby('Agent Name')['Total Feedback'].sum() 
df9['Chat-feedback Percentage'] = (df9['Total Feedback'] / df9['Total Chats']) * 100

# %%
df9
# Out:
#                         Total Chats  Total Feedback  Chat-feedback Percentage
# Agent Name
# Aditya Shinde                   277             153                 55.234657
# Aditya_iot                      231             131                 56.709957
# Ameya Jain                      322             228                 70.807453
# Anirudh                          81              39                 48.148148
# Ankitjha                          5               3                 60.000000
# Anurag Tiwari                     4               3                 75.000000
# Aravind                         366             233                 63.661202
# Ashad Nasim                      18               9                 50.000000
# Ayushi Mishra                   514             329                 64.007782
# Bharath                         369             247                 66.937669
# Boktiar Ahmed Bappy             452             311                 68.805310
# ...

# %% [markdown]
# ###### Ans13:
# Total contributation hour for each and every agents weekly basis

# %%
# here we need to use Agent logging csv file 
df10 = pd.read_csv("E:\DATA SCIENCE\data fsds_\AgentLogingReport.csv" , index_col = 'SL No')

# %%
df10
# Out:
#                     Agent       Date Login Time Logout Time   Duration
# SL No
# 1      Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 2          Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 3           Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 4         Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 5                  Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ...                   ...        ...        ...         ...        ...
# 996          Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 997               Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 998        Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 999          Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 1000                Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
# [1000 rows x 5 columns]

# %%
df10.dtypes
# Out:
# Agent          object
# Date           object
# Login Time     object
# Logout Time    object
# Duration       object
# dtype: object

# %%
l = df10['Duration'].str.split(":")
df10['hours'] = (l.str[0].astype(int) * 3600 + l.str[1].astype(int) * 60 + l.str[2].astype(int)) / 3600
df10['Date'] = pd.to_datetime(df10['Date'])
df10['Week'] = df10['Date'].dt.week
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10824\1870757178.py:4: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df10['Week'] = df10['Date'].dt.week

# %%
df11 = df10.groupby(['Week','Agent'])['hours'].sum()
df11 = df11.to_frame(name='hour contributed per week')
df11
# Out:
#                       hour contributed per week
# Week Agent
# 26   Tarun                           514.138889
# 29   Aditya_iot                        6.095278
#      Ameya Jain                       24.083056
#      Anurag Tiwari                     0.264444
#      Aravind                          24.235556
# ...                                         ...
# 30   Sudhanshu Kumar                  21.776389
#      Suraj S Bilgi                    12.559167
#      Swati                             6.142500
#      Wasim                            28.553611
#      Zeeshan                          24.661111
#
# [89 rows x 1 columns]

# %% [markdown]
# ###### Ans14:
# total percentage of active hour for a month

# %%
df12 = ((df10.groupby('Agent')['hours'].sum()) / (30*24)) * 100
df12 = df12.to_frame('Active hours percentage')
df12
# Out:
#                         Active hours percentage
# Agent
# Aditya Shinde                          0.005015
# Aditya_iot                             2.184877
# Amersh                                 0.425540
# Ameya Jain                             5.843827
# Ankitjha                               0.314853
# Anurag Tiwari                          0.385957
# Aravind                                3.374884
# Ayushi Mishra                          5.294676
# Bharath                                6.677315
# Boktiar Ahmed Bappy                    5.592863
# Chaitra K Hiremath                     4.767438
# Deepranjan Gupta                      14.760455
# Dibyanshu                              7.304977
# Harikrishnan Shaji                     7.460378
# Hrisikesh Neogi                        7.995640
# Hyder Abbas                            0.053897
# Ineuron Intelligence                   0.201196
# Ishawant Kumar                         7.191512
# ...
