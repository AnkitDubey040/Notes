# %%
import pandas as pd

# to read a file:

# %%
df =pd.read_excel("E:\DATA SCIENCE\data fsds_\Attribute Dataset.xlsx")

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
# agar data ko ir mei daal de i.e. jupyter project wali mei to hume path nhi dena sirf file name i.e. "Attribute Dataset.xlsx likhna hai aur output aa jayega"

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# suppose hume isi file ki sheet 2 read karni hai :
pd.read_excel("E:\DATA SCIENCE\data fsds_\Attribute Dataset.xlsx",sheet_name = "ankitsheet")
# Out:
#       egagesa     kyr    fh Unnamed: 3
# 0        egtj    fyrk   hsr        srh
# 1    eageagea   yrkyr   hsr         sr
# 2   aegeageag    kyrk   srh      srhsr
# 3        tuyk   yrkyr   rsh          h
# 4         kut     kyr    sr        srh
# 5        kyrk    kyrk   srh         sr
# 6         utk     hsr   yrk        NaN
# 7         NaN      sr   hsr         sr
# 8       rgsrh  hsrhsr  srju        NaN
# 9           h     NaN   hsr         hh
# 10        NaN     srh   NaN          h
# 11        NaN     NaN   NaN        srh
# 12        NaN      sr   NaN        NaN

# %%
# first row ko ye column name manta hai by default par hum usse eliminate kar sakte hai 
# like this :

# %%
pd.read_excel("E:\DATA SCIENCE\data fsds_\Attribute Dataset.xlsx",sheet_name = "ankitsheet", header= None)
# Out:
#             0       1     2      3
# 0     egagesa     kyr    fh    NaN
# 1        egtj    fyrk   hsr    srh
# 2    eageagea   yrkyr   hsr     sr
# 3   aegeageag    kyrk   srh  srhsr
# 4        tuyk   yrkyr   rsh      h
# 5         kut     kyr    sr    srh
# 6        kyrk    kyrk   srh     sr
# 7         utk     hsr   yrk    NaN
# 8         NaN      sr   hsr     sr
# 9       rgsrh  hsrhsr  srju    NaN
# 10          h     NaN   hsr     hh
# 11        NaN     srh   NaN      h
# 12        NaN     NaN   NaN    srh
# 13        NaN      sr   NaN    NaN

# %%
# to give our own column name:

# %%
pd.read_excel("E:\DATA SCIENCE\data fsds_\Attribute Dataset.xlsx",sheet_name = "ankitsheet", header= None, names = ["C1" ,"C2","C3","C4"])
# Out:
#            C1      C2    C3     C4
# 0     egagesa     kyr    fh    NaN
# 1        egtj    fyrk   hsr    srh
# 2    eageagea   yrkyr   hsr     sr
# 3   aegeageag    kyrk   srh  srhsr
# 4        tuyk   yrkyr   rsh      h
# 5         kut     kyr    sr    srh
# 6        kyrk    kyrk   srh     sr
# 7         utk     hsr   yrk    NaN
# 8         NaN      sr   hsr     sr
# 9       rgsrh  hsrhsr  srju    NaN
# 10          h     NaN   hsr     hh
# 11        NaN     srh   NaN      h
# 12        NaN     NaN   NaN    srh
# 13        NaN      sr   NaN    NaN

# %%
# to print first 2 records
df.head(2)
# Out:
#      Dress_ID   Style Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852    Sexy   Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089  Casual   Low     0.0    L  Summer   o-neck        Petal
#
#   waiseline    Material FabricType Decoration Pattern Type  Recommendation
# 0    empire         NaN    chiffon    ruffles       animal               1
# 1   natural  microfiber        NaN    ruffles       animal               0

# %%
# to show last 4 records
df.tail(5)
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 495  713391965  Casual      Low     4.7     M  Spring     o-neck         full
# 496  722565148    Sexy      Low     4.3  free  Summer     o-neck         full
# 497  532874347  Casual  Average     4.7     M  Summer     v-neck         full
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline  Material  FabricType Decoration Pattern Type  Recommendation
# 495   natural  polyster         NaN        NaN        solid               1
# 496    empire    cotton         NaN        NaN          NaN               0
# 497    empire    cotton         NaN       lace        solid               1
# 498    empire      silk  broadcloth   applique        print               1
# 499    empire    cotton    Corduroy       lace        solid               0

# %%
#csv:comma seperated value
#haberman dataset
pd.read_csv("E:\DATA SCIENCE\data fsds_\haberman.csv",header = None, names = ["Age" ," Patient's year of operation" , "Number of Positive" ,"Survival Status"])
# Out:
#      Age   Patient's year of operation  Number of Positive  Survival Status
# 0     30                            64                   1                1
# 1     30                            62                   3                1
# 2     30                            65                   0                1
# 3     31                            59                   2                1
# 4     31                            65                   4                1
# ..   ...                           ...                 ...              ...
# 301   75                            62                   1                1
# 302   76                            67                   0                1
# 303   77                            65                   3                1
# 304   78                            65                   1                2
# 305   83                            58                   2                2
#
# [306 rows x 4 columns]

# %%
# humne haberman ki ek copy banai testhaberman aur us csv mei sab commas ki jagah @ daal diya ab hume vo file read karni hai

# %%
pd.read_csv("testhaberman.csv")
# Out:
#       30@64@1@1
# 0     30@62@3@1
# 1     30@65@0@1
# 2     31@59@2@1
# 3     31@65@4@1
# 4    33@58@10@1
# ..          ...
# 300   75@62@1@1
# 301   76@67@0@1
# 302   77@65@3@1
# 303   78@65@1@2
# 304   83@58@2@2
#
# [305 rows x 1 columns]

# %%
pd.read_csv("testhaberman.csv" , sep= "@")
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# ..   ..  ..  ..  ...
# 300  75  62   1    1
# 301  76  67   0    1
# 302  77  65   3    1
# 303  78  65   1    2
# 304  83  58   2    2
#
# [305 rows x 4 columns]

# %%
# dataset from github repisitory
# data khol lo link ke thr github pe uspe ek option hoga raw
#us raw pe click karo aur full data show hoga ab vo url ko de do yahan pe raw wala

pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/master/Smarket.csv")
# Out:
#       Year   Lag1   Lag2   Lag3   Lag4   Lag5   Volume  Today Direction
# 0     2001  0.381 -0.192 -2.624 -1.055  5.010  1.19130  0.959        Up
# 1     2001  0.959  0.381 -0.192 -2.624 -1.055  1.29650  1.032        Up
# 2     2001  1.032  0.959  0.381 -0.192 -2.624  1.41120 -0.623      Down
# 3     2001 -0.623  1.032  0.959  0.381 -0.192  1.27600  0.614        Up
# 4     2001  0.614 -0.623  1.032  0.959  0.381  1.20570  0.213        Up
# ...    ...    ...    ...    ...    ...    ...      ...    ...       ...
# 1245  2005  0.422  0.252 -0.024 -0.584 -0.285  1.88850  0.043        Up
# 1246  2005  0.043  0.422  0.252 -0.024 -0.584  1.28581 -0.955      Down
# 1247  2005 -0.955  0.043  0.422  0.252 -0.024  1.54047  0.130        Up
# 1248  2005  0.130 -0.955  0.043  0.422  0.252  1.42236 -0.298      Down
# 1249  2005 -0.298  0.130 -0.955  0.043  0.422  1.38254 -0.489      Down
#
# [1250 rows x 9 columns]

# %%
#humne apne data ki github repo bna ke call kiya hai :
# another dataset :
pd.read_csv("https://raw.githubusercontent.com/sudh9931/data/main/haberman.csv")
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# ..   ..  ..  ..  ...
# 300  75  62   1    1
# 301  76  67   0    1
# 302  77  65   3    1
# 303  78  65   1    2
# 304  83  58   2    2
#
# [305 rows x 4 columns]

# %%
# reading data from website: #read html
a = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
type(a)  # it is a list an dnot a dataframe
# Out:
# list

# %%
a
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
len(a)
# Out:
# 1

# %%
a[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(a[0]) # now this is a dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
# to open json file an dcreate structure of it :
# json: key value pair data
#json: java script object notation file

# %%
pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
 js = pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")

# %%
js.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels',
#        'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'body', 'reactions', 'timeline_url',
#        'performed_via_github_app', 'state_reason', 'draft', 'pull_request'],
#       dtype='object')

# %%
js["user"] # user column ke andar ke records:
# Out:
# 0     {'login': 'akald', 'id': 59920376, 'node_id': ...
# 1     {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 2     {'login': 'weikhor', 'id': 36619387, 'node_id'...
# 3     {'login': 'meeseeksmachine', 'id': 39504233, '...
# 4     {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 5     {'login': 'weikhor', 'id': 36619387, 'node_id'...
# 6     {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 7     {'login': 'jonashaag', 'id': 175722, 'node_id'...
# 8     {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 9     {'login': 'abalkin', 'id': 535197, 'node_id': ...
# 10    {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 11    {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 12    {'login': 'abalkin', 'id': 535197, 'node_id': ...
# 13    {'login': 'nealxm', 'id': 88364802, 'node_id':...
# 14    {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 15    {'login': 'lithomas1', 'id': 47963215, 'node_i...
# 16    {'login': 'ambujpawar', 'id': 19887541, 'node_...
# ...

# %%
js["user"][0]
# Out:
# {'login': 'akald',
#  'id': 59920376,
#  'node_id': 'MDQ6VXNlcjU5OTIwMzc2',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/59920376?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/akald',
#  'html_url': 'https://github.com/akald',
#  'followers_url': 'https://api.github.com/users/akald/followers',
#  'following_url': 'https://api.github.com/users/akald/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/akald/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/akald/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/akald/subscriptions',
#  'organizations_url': 'https://api.github.com/users/akald/orgs',
#  'repos_url': 'https://api.github.com/users/akald/repos',
#  'events_url': 'https://api.github.com/users/akald/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/akald/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
# ab hum attribute dataset wale ko json mei convert karenge:
df.to_json("testjsonattributedataset.json")

# %%
pwd
# Out:
# 'C:\\Users\\HP\\Jupyter codes'

# %%
#ye data json mei covert ho ke present working directory mei sdave ho jayega 
#hum online json viewer mei ja ke usko dekh bhi sakte hai esily

# %%
# sql database mei fetch karke record fir hum for loop laga ke dekhte the data

# %%
#sparx dataframe is faster than pandas

# %%
# to store info permanently in ypur system 

df.to_csv("E:\DATA SCIENCE\data fsds\conversiontocsvattributedataset.csv")

# %%
# to store data but with differwent seperator instead of comma:

df.to_csv("E:\DATA SCIENCE\data fsds\conversiontocsvattributedataset123.csv",sep = "#")

# %%
# suppose we dont want consider row indexes

df.to_csv("E:\DATA SCIENCE\data fsds\conversiontocsvattributedataset1111.csv",index = False)

# %%
''' 
now we have two datasets attribute dataset and dress sales dataset which are botjh connected by dress ID
so we want to JOIN these two tables so we do it as follows : 
using mysql :
'''
# Out:
# ' \nnow we have two datasets attribute dataset and dress sales dataset which are botjh connected by dress ID\nso we want to JOIN these two tables so we do it as follows : \nusing mysql :\n\n\n'

# %%
'''
Mysql : (through python or mysqlsql)
    
    1. Create a  table attribute dataset and dress dataset
    2. Do a bulk load for these two table for respective dataset 
    3. read these dataset in pandas as a dataframe 
    
    4. Convert attribute dataset in json format 
    5. Store this dataset into mongodb
    
    
    6. in sql task try to perform left join operation with attrubute dataset and dress dataset on column Dress_ID
    7. Write a sql query to find out how many unique dress that we have based on dress id 
    8. Try to find out how mnay dress is having recommendation 0
    9. Try to find out total dress sell for individual dress id 
    10. Try to find out a third highest most selling dress id 
    
'''
# Out:
# '\nMysql : (through python or mysqlsql)\n    \n    1. Create a  table attribute dataset and dress dataset\n    2. Do a bulk load for these two table for respective dataset \n    3. read these dataset in pandas as a dataframe \n    \n    4. Convert attribute dataset in json format \n    5. Store this dataset into mongodb\n    \n    \n    6. in sql task try to perform left join operation with attrubute dataset and dress dataset on column Dress_ID\n    7. Write a sql query to find out how many unique dress that we have based on dress id \n    8. Try to find out how mnay dress is having recommendation 0\n    9. Try to find out total dress sell for individual dress id \n    10. Try to find out a third highest most selling dress id \n    \n'
