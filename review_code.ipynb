# %%
from flask import Flask , render_template , request , jsonify

# %%
from bs4 import BeautifulSoup as bs

# %%
from urllib.request import urlopen as urReq

# %%
flipcart_url = "https://www.flipkart.com/search?q="+"iphone11"

# %%
flipcart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone11'

# %%
response_website = urReq(flipcart_url)

# %%
data_flipcart = response_website.read()

# %%
beautifyed_html  = bs(data_flipcart,"html.parser")

# %%
beautifyed_html
# Out:
# <!DOCTYPE html>
# ...

# %%
bigbox = beautifyed_html.find_all("div" , {"class":"_1AtVbE col-12-12" })

# %%
len(bigbox)
# Out:
# 30

# %%
'''
since 30 objects so 30 bigboxes needed so on a link we are looking for a href to go to that link

we can even see the list of available products 
'''

# %%
bigbox[6] # info about one single box
# Out:
# <div class="_1AtVbE col-12-12"><div class="_13oc-S"><div data-id="MOBFWQ6BYYV3FCU7" style="width:100%"><div class="_2kHMtA"><a class="_1fQZEK" href="/apple-iphone-11-red-64-gb/p/itmc3935326f2feb?pid=MOBFWQ6BYYV3FCU7&amp;lid=LSTMOBFWQ6BYYV3FCU7ZCY7Y9&amp;marketplace=FLIPKART&amp;q=iphone11&amp;store=tyy%2F4io&amp;srno=s_1_5&amp;otracker=search&amp;fm=organic&amp;iid=c2efcf6f-353d-4c11-b1b7-beec6bc041e3.MOBFWQ6BYYV3FCU7.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=dgmgshroog0000001663960930039&amp;qH=d6db477051465f9a" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="APPLE iPhone 11 (Red, 64 GB)" class="_396cs4 _3exPp9" src="https://rukminim1.flixcart.com/image/312/312/k2jbyq80pkrrdj/mobile-refurbished/q/z/g/iphone-11-128-a-mwm32hn-a-apple-0-original-imafkg25hjmuy98e.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input c
# ...

# %%
''' 
since we cannot do this manually so we need to search for href
'''
# Out:
# ' \nsince we cannot do this manually so we need to search for href\n'

# %%
bigbox[6].div.div.div.a["href"]
# so we are able to see this and we need to append this url with original url so we will see that we have complete url
# Out:
# '/apple-iphone-11-red-64-gb/p/itmc3935326f2feb?pid=MOBFWQ6BYYV3FCU7&lid=LSTMOBFWQ6BYYV3FCU7ZCY7Y9&marketplace=FLIPKART&q=iphone11&store=tyy%2F4io&srno=s_1_5&otracker=search&fm=organic&iid=c2efcf6f-353d-4c11-b1b7-beec6bc041e3.MOBFWQ6BYYV3FCU7.SEARCH&ppt=None&ppn=None&ssid=dgmgshroog0000001663960930039&qH=d6db477051465f9a'

# %%
"https://www.flipkart.com/search?q=iphone11"+bigbox[2].div.div.div.a['href']
# Out:
# 'https://www.flipkart.com/search?q=iphone11/apple-iphone-11-white-128-gb/p/itme32df47ea6742?pid=MOBFWQ6B7KKRXDDS&lid=LSTMOBFWQ6B7KKRXDDSULUZ0N&marketplace=FLIPKART&q=iphone11&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=c2efcf6f-353d-4c11-b1b7-beec6bc041e3.MOBFWQ6B7KKRXDDS.SEARCH&ppt=None&ppn=None&ssid=dgmgshroog0000001663960930039&qH=d6db477051465f9a'

# %%
product6 = "https://www.flipkart.com" + bigbox[6].div.div.div.a['href']

# %%
import requests

# %%
product66 = requests.get(product6)

# %%
product66
# Out:
# <Response [200]>

# %%
product6
# Out:
# 'https://www.flipkart.com/apple-iphone-11-red-64-gb/p/itmc3935326f2feb?pid=MOBFWQ6BYYV3FCU7&lid=LSTMOBFWQ6BYYV3FCU7ZCY7Y9&marketplace=FLIPKART&q=iphone11&store=tyy%2F4io&srno=s_1_5&otracker=search&fm=organic&iid=c2efcf6f-353d-4c11-b1b7-beec6bc041e3.MOBFWQ6BYYV3FCU7.SEARCH&ppt=None&ppn=None&ssid=dgmgshroog0000001663960930039&qH=d6db477051465f9a'

# %%
" our requirement is to get review for the product so we call beautify again"
# Out:
# ' our requirement is to get review for the product so we call beautify again'

# %%
bs(product6,"html.parser")
# Out:
# https://www.flipkart.com/apple-iphone-11-red-64-gb/p/itmc3935326f2feb?pid=MOBFWQ6BYYV3FCU7&amp;lid=LSTMOBFWQ6BYYV3FCU7ZCY7Y9&amp;marketplace=FLIPKART&amp;q=iphone11&amp;store=tyy%2F4io&amp;srno=s_1_5&amp;otracker=search&amp;fm=organic&amp;iid=c2efcf6f-353d-4c11-b1b7-beec6bc041e3.MOBFWQ6BYYV3FCU7.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=dgmgshroog0000001663960930039&amp;qH=d6db477051465f9a

# %%
# we have to encode data now :
product66.encoding= 'utf-8'

# %%
product6_page = bs(product66.text,"html.parser")
# we are creating a text file of this link

# %%
# now we need to reach out to the box containing reviews and find the code for text on the Inspect >Element
all_review = product6_page.find_all('div', {"class":"_16PBlm"})

# %%
all_review[0].div.div.text
# Out:
# '5Perfect product!Value for money5 star rating Excellent cameraBattery backup full day in single charge.Tougher and water resistant design, glossy back.The screen has excellent brightness and contrast.Apple A13 Bionic is the fastest smartphone chip on the planet.Excellent battery life, fast charging support.Stereo speakers with great quality.READ MOREChirag RajputCertified Buyer, KolkataFeb, 202118815PermalinkReport Abuse'

# %%
len(all_review)
# Out:
# 11

# %%
all_review[0].div.div.find_all('p',{" class":"_2sc7ZR _2V5EHH"})
# Out:
# []

# %%
#printing a particular review
all_review[0].div.find_all('div' , {'class' : ""})[0].div.text
# Out:
# 'What a camera .....just awesome ..you can feel this iPhone just awesome . Good for gaming also ...try pubg in hd it’s just wow'
